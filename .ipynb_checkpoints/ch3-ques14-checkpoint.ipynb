# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import OLSInfluence
from pandas.plotting import scatter_matrix 
from mpl_toolkits.mplot3d import Axes3D
from statsmodels.stats.outliers_influence import OLSInfluence
# %matplotlib inline
plt.style.use('ggplot')

# %%
np.random.seed(0)
x1=np.random.random(100)
x2=0.5*x1+np.random.randn(100)/10
y=2+2*x1+0.3*x2+np.random.randn(100)

# %%
corr=np.corrcoef(x1,x2)
print('correlation',corr)
df=pd.DataFrame({'y':y,'x1':x1,'x2':x2})
scatter_matrix(df, figsize=(10,10),alpha=0.5)
# Out:
# correlation [[1.         0.81926336]
#  [0.81926336 1.        ]]
# array([[<AxesSubplot:xlabel='y', ylabel='y'>,
#         <AxesSubplot:xlabel='x1', ylabel='y'>,
#         <AxesSubplot:xlabel='x2', ylabel='y'>],
#        [<AxesSubplot:xlabel='y', ylabel='x1'>,
#         <AxesSubplot:xlabel='x1', ylabel='x1'>,
#         <AxesSubplot:xlabel='x2', ylabel='x1'>],
#        [<AxesSubplot:xlabel='y', ylabel='x2'>,
#         <AxesSubplot:xlabel='x1', ylabel='x2'>,
#         <AxesSubplot:xlabel='x2', ylabel='x2'>]], dtype=object)

# %%
X=sm.add_constant(df[['x1','x2']])
model=sm.OLS(y,X)
est=model.fit()
print(est.summary())
# beta0 is 1.9217 , beta1 is 1.2007 and beta2 is 1.4931 while reale values are 2,2 and 0.3 respectively
# based on p values the null hypothesis fo const beta2 cannot be rejected.
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.246
# Method:                 Least Squares   F-statistic:                     17.16
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           4.16e-07
# Time:                        19:00:31   Log-Likelihood:                -139.04
# No. Observations:                 100   AIC:                             284.1
# Df Residuals:                      97   BIC:                             291.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9217      0.191     10.071      0.000       1.543       2.300
# x1             1.2007      0.597      2.011      0.047       0.016       2.385
# x2             1.4931      0.991      1.507      0.135      -0.473       3.459
# ==============================================================================
# Omnibus:                        0.196   Durbin-Watson:                   2.109
# Prob(Omnibus):                  0.907   Jarque-Bera (JB):                0.026
# Skew:                           0.032   Prob(JB):                        0.987
# Kurtosis:                       3.046   Cond. No.                         13.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X1=sm.add_constant(x1)
model1=sm.OLS(y,X1)
est1=model1.fit()
print(est1.summary())
# null hypothesis has to be rejected for beta1
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.244
# Model:                            OLS   Adj. R-squared:                  0.236
# Method:                 Least Squares   F-statistic:                     31.64
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.76e-07
# Time:                        19:00:34   Log-Likelihood:                -140.20
# No. Observations:                 100   AIC:                             284.4
# Df Residuals:                      98   BIC:                             289.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9548      0.191     10.247      0.000       1.576       2.333
# x1             1.9378      0.344      5.625      0.000       1.254       2.621
# ==============================================================================
# Omnibus:                        0.305   Durbin-Watson:                   2.127
# Prob(Omnibus):                  0.858   Jarque-Bera (JB):                0.050
# Skew:                          -0.005   Prob(JB):                        0.975
# Kurtosis:                       3.109   Cond. No.                         4.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X2=sm.add_constant(x2)
model2=sm.OLS(y,X2)
est2=model2.fit()
print(est2.summary())
# null hypothesis has to be rejected for beta2
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.231
# Model:                            OLS   Adj. R-squared:                  0.223
# Method:                 Least Squares   F-statistic:                     29.37
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           4.29e-07
# Time:                        19:00:37   Log-Likelihood:                -141.09
# No. Observations:                 100   AIC:                             286.2
# Df Residuals:                      98   BIC:                             291.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0721      0.178     11.623      0.000       1.718       2.426
# x1             3.1255      0.577      5.419      0.000       1.981       4.270
# ==============================================================================
# Omnibus:                        0.213   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.899   Jarque-Bera (JB):                0.187
# Skew:                           0.100   Prob(JB):                        0.911
# Kurtosis:                       2.929   Cond. No.                         6.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df2=pd.DataFrame({'y':[6],'x1':[0.1],'x2':[0.8]})
df=df.append(df2)
X_both=sm.add_constant(df.iloc[:,1:])

# model with x1 and x2
est_both=sm.OLS(df['y'],X_both).fit()
print(est_both.summary())

# studentized residuals vs leverages
fig, ax = plt.subplots(figsize=(12,8))
fig = sm.graphics.influence_plot(est_both, alpha  = 0.05, ax = ax, criterion="cooks")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.295
# Method:                 Least Squares   F-statistic:                     22.12
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.15e-08
# Time:                        19:04:00   Log-Likelihood:                -144.56
# No. Observations:                 102   AIC:                             295.1
# Df Residuals:                      99   BIC:                             303.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9605      0.195     10.033      0.000       1.573       2.348
# x1             0.1403      0.464      0.302      0.763      -0.780       1.061
# x2             3.4044      0.717      4.751      0.000       1.983       4.826
# ==============================================================================
# Omnibus:                        0.021   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.990   Jarque-Bera (JB):                0.144
# Skew:                           0.020   Prob(JB):                        0.930
# Kurtosis:                       2.820   Cond. No.                         9.07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# model with x1
print(sm.OLS(df['y'],sm.add_constant(df['x1'])).fit().summary())
fig, ax = plt.subplots(figsize=(5,5))
fig = sm.graphics.influence_plot(sm.OLS(df['y'],sm.add_constant(df['x1'])).fit(), alpha  = 0.05, ax = ax, criterion="cooks")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.143
# Method:                 Least Squares   F-statistic:                     17.82
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           5.35e-05
# Time:                        19:04:46   Log-Likelihood:                -155.03
# No. Observations:                 102   AIC:                             314.1
# Df Residuals:                     100   BIC:                             319.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1830      0.209     10.437      0.000       1.768       2.598
# x1             1.6099      0.381      4.222      0.000       0.853       2.366
# ==============================================================================
# Omnibus:                       10.813   Durbin-Watson:                   1.627
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               13.013
# Skew:                           0.579   Prob(JB):                      0.00149
# Kurtosis:                       4.311   Cond. No.                         4.25
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# model with x2
print(sm.OLS(df['y'],sm.add_constant(df['x2'])).fit().summary())
# finding outlier
fig, ax = plt.subplots(figsize=(5,5))
fig = sm.graphics.influence_plot(sm.OLS(df['y'],sm.add_constant(df['x2'])).fit(), alpha  = 0.05, ax = ax, criterion="cooks")
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.308
# Model:                            OLS   Adj. R-squared:                  0.301
# Method:                 Least Squares   F-statistic:                     44.55
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.40e-09
# Time:                        19:05:24   Log-Likelihood:                -144.61
# No. Observations:                 102   AIC:                             293.2
# Df Residuals:                     100   BIC:                             298.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9873      0.173     11.469      0.000       1.644       2.331
# x2             3.5488      0.532      6.675      0.000       2.494       4.604
# ==============================================================================
# Omnibus:                        0.023   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.989   Jarque-Bera (JB):                0.142
# Skew:                           0.025   Prob(JB):                        0.931
# Kurtosis:                       2.824   Cond. No.                         5.71
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
