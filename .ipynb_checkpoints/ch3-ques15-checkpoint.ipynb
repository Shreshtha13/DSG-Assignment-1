# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import OLSInfluence
from pandas.plotting import scatter_matrix 
from mpl_toolkits.mplot3d import Axes3D
import collections
# %matplotlib inline
plt.style.use('ggplot')

# %%
df=pd.read_csv('Boston.csv')
y=df.crim
simple_coeff=collections.defaultdict(list)
for i in list(df.drop('crim',axis=1)):
    X=sm.add_constant(df[i])
    model=sm.OLS(y,X)
    est=model.fit()
#     print(est.summary())
    print(i,est.pvalues[1])
    print('\n \n')
    simple_coeff[i]=est.params[1]
# Out:
# zn 5.506472107679307e-06
#
#
#
# indus 1.4503489330272395e-21
#
#
#
# chas 0.2094345015352004
#
#
#
# nox 3.751739260356923e-23
#
#
#
# rm 6.346702984687839e-07
#
#
#
# age 2.8548693502441573e-16
#
#
#
# dis 8.519948766926326e-19
#
#
#
# rad 2.6938443981864414e-56
#
#
#
# tax 2.357126835257048e-47
#
#
#
# ptratio 2.942922447359816e-11
#
#
#
# black 2.487273973773734e-19
#
#
#
# lstat 2.6542772314731968e-27
#
#
#
# medv 1.1739870821943694e-19

# %%
X=sm.add_constant(df.iloc[:,1:])
y=df.crim
model1=sm.OLS(y,X)
estimate=model1.fit()
print(estimate.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     31.47
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.57e-56
# Time:                        11:37:04   Log-Likelihood:                -1653.3
# No. Observations:                 506   AIC:                             3335.
# Df Residuals:                     492   BIC:                             3394.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.0332      7.235      2.354      0.019       2.818      31.248
# ...

# %%
# multiple linear regression
multi_coeff=estimate.params[1:]
simple_coeffs=pd.Series(simple_coeff)
simple_coeffs=simple_coeffs[0:]
fig,ax=plt.subplots(figsize=(8,8))
ax.scatter(simple_coeffs.values,multi_coeff.values)
ax.set_xlabel('univariate coefficients')
ax.set_ylabel('multivariate coefficients')
for label in list(df.drop('crim',axis=1)):
    plt.annotate(label,xy=(simple_coeffs[label],multi_coeff[label]))

# %%
model_poly = smf.ols('crim ~ dis + I(dis**2)+I(dis**3)', data = df)
estimate_poly = model_poly.fit()
print(estimate_poly.summary())
fig,poly_ax=plt.subplots(figsize=(10,10))
poly_ax.scatter(df['dis'],df['crim'],facecolors='none',edgecolors='red',label='data')
poly_ax.scatter(df['dis'],estimate_poly.fittedvalues,facecolors='none',edgecolors='k',label='model')
poly_ax.legend()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.274
# Method:                 Least Squares   F-statistic:                     64.37
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           3.14e-35
# Time:                        11:47:15   Log-Likelihood:                -1724.0
# No. Observations:                 506   AIC:                             3456.
# Df Residuals:                     502   BIC:                             3473.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      30.0476      2.446     12.285      0.000      25.242      34.853
# ...

# %%
model_poly = smf.ols('crim ~ zn + I(zn**2)+I(zn**3)', data = df)
estimate_poly = model_poly.fit()
print(estimate_poly.summary())
fig,poly_ax=plt.subplots(figsize=(10,10))
poly_ax.scatter(df['zn'],df['crim'],facecolors='none',edgecolors='red',label='data')
poly_ax.scatter(df['zn'],estimate_poly.fittedvalues,facecolors='none',edgecolors='k',label='model')
poly_ax.legend()
df.head()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     10.35
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.28e-06
# Time:                        11:48:50   Log-Likelihood:                -1791.2
# No. Observations:                 506   AIC:                             3590.
# Df Residuals:                     502   BIC:                             3607.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      4.8461      0.433     11.192      0.000       3.995       5.697
# ...

# %%
model_poly = smf.ols('crim ~ indus + I(indus**2)+I(indus**3)', data = df)
estimate_poly = model_poly.fit()
print(estimate_poly.summary())
fig,poly_ax=plt.subplots(figsize=(10,10))
poly_ax.scatter(df['indus'],df['crim'],facecolors='none',edgecolors='red',label='data')
poly_ax.scatter(df['indus'],estimate_poly.fittedvalues,facecolors='none',edgecolors='k',label='model')
poly_ax.legend()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.260
# Model:                            OLS   Adj. R-squared:                  0.255
# Method:                 Least Squares   F-statistic:                     58.69
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           1.55e-32
# Time:                        11:50:04   Log-Likelihood:                -1730.3
# No. Observations:                 506   AIC:                             3469.
# Df Residuals:                     502   BIC:                             3486.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         3.6626      1.574      2.327      0.020       0.570       6.755
# ...

# %%
model_poly = smf.ols('crim ~ nox + I(nox**2)+I(nox**3)', data = df)
estimate_poly = model_poly.fit()
print(estimate_poly.summary())
fig,poly_ax=plt.subplots(figsize=(10,10))
poly_ax.scatter(df['nox'],df['crim'],facecolors='none',edgecolors='red',label='data')
poly_ax.scatter(df['nox'],estimate_poly.fittedvalues,facecolors='none',edgecolors='k',label='model')
poly_ax.legend()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.297
# Model:                            OLS   Adj. R-squared:                  0.293
# Method:                 Least Squares   F-statistic:                     70.69
# Date:                Tue, 13 Apr 2021   Prob (F-statistic):           3.81e-38
# Time:                        11:50:42   Log-Likelihood:                -1717.2
# No. Observations:                 506   AIC:                             3442.
# Df Residuals:                     502   BIC:                             3459.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     233.0866     33.643      6.928      0.000     166.988     299.185
# ...
